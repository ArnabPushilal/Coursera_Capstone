# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
import numpy as np
import pandas as pd
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML
from pandas.io.json import json_normalize
import folium # plotting library
CLIENT_ID = 'KJILOVWXJS1ULPC0VURUALFW1S2ETMZEIMQNNO0MO2DRWDHQ' # your Foursquare ID
CLIENT_SECRET = 'WS5L15J3UEHCD5WNX4YM3QPPCSIYZ32GJLPNHC1FWBPAZCVP' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# READ DATA AND CLEAN

# %%
Data=pd.read_html(url)

df=Data[0]

df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# Removing rows with Not assigned

# %%
a=[]

for i,v in enumerate(df['Borough']):
    a.append(v != "Not assigned" )
         
df1=df.loc[a,:]
        
df1.reset_index(drop=True,inplace=True)
df1.shape
# Out:
# (103, 3)

# %%
df1.shape
# Out:
# (103, 3)

# %%
lat=pd.read_csv("https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv")

# %% [markdown]
# CREATING A DATA FRAME WITH LATTITUDE AND LONGITUDE

# %%
lat
Merged=df1.merge(lat)
c=[]

for h in Merged['Borough']:
    c.append(h.split(' ')[-1]=="Toronto")
c
# Out:
# [False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False]

# %% [markdown]
# FOURSQUARE ACCESSS

# %%
import requests
CLIENT_ID = 'KJILOVWXJS1ULPC0VURUALFW1S2ETMZEIMQNNO0MO2DRWDHQ' # your Foursquare ID
CLIENT_SECRET = 'USGY1XID1RLVTJRMPSPLCTV1YZ21MU43SY5FQ4COIRJPVSDG' # your Foursquare Secret
VERSION = '20180604'

LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KJILOVWXJS1ULPC0VURUALFW1S2ETMZEIMQNNO0MO2DRWDHQ
# CLIENT_SECRET:USGY1XID1RLVTJRMPSPLCTV1YZ21MU43SY5FQ4COIRJPVSDG

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Canada are 43.6534817, -79.3839347.

# %%
map_canada = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(Merged['Latitude'], Merged['Longitude'], Merged['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_canada)  
    
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Finding the ones with "toronto"

# %%
c=[]

for h in Merged['Borough']:
    c.append(h.split(' ')[-1]=="Toronto")
df_final=Merged.iloc[c,:]

# %%
df_final.reset_index(drop=True,inplace=True)

# %%
df_final
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M4E      East Toronto
# 5          M5E  Downtown Toronto
# 6          M5G  Downtown Toronto
# 7          M6G  Downtown Toronto
# 8          M5H  Downtown Toronto
# 9          M6H      West Toronto
# 10         M5J  Downtown Toronto
# 11         M6J      West Toronto
# 12         M4K      East Toronto
# 13         M5K  Downtown Toronto
# 14         M6K      West Toronto
# 15         M4L      East Toronto
# 16         M5L  Downtown Toronto
# 17         M4M      East Toronto
# 18         M4N   Central Toronto
# 19         M5N   Central Toronto
# 20         M4P   Central Toronto
# 21         M5P   Central Toronto
# 22         M6P      West Toronto
# 23         M4R   Central Toronto
# 24         M5R   Central Toronto
# 25         M6R      West Toronto
# 26         M4S   Central Toronto
# ...

# %%
import requests
vname=[]
vlat=[]
vlon=[]
radius = 500
for name, lat, lng in zip(df_final['Postal Code'], df_final['Latitude'], df_final['Longitude']):
            print(name)
            url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            results = requests.get(url).json()
            vname.append(requests.get(url).json()["response"]['groups'][0]['items'][0]['venue']['name'])
            vlat.append(requests.get(url).json()["response"]['groups'][0]['items'][0]['venue']['location']['lat'])
            vlon.append(requests.get(url).json()["response"]['groups'][0]['items'][0]['venue']['location']['lng'])
# Out:
# M5A
# M7A
# M5B
# M5C
# M4E
# M5E
# M5G
# M6G
# M5H
# M6H
# M5J
# M6J
# M4K
# M5K
# M6K
# M4L
# M5L
# M4M
# M4N
# M5N
# M4P
# M5P
# M6P
# M4R
# M5R
# M6R
# M4S
# M5S
# M6S
# M4T
# M5T
# M4V
# M5V
# M4W
# M5W
# M4X
# M5X
# M4Y
# M7Y

# %% [markdown]
# Creating a DataFrame out of name,latitude & longitude

# %%
Restu=pd.DataFrame(zip(vname,vlat,vlon),columns=['Name','Latitude','Longitude'])
Restu
# Out:
#                                                  Name   Latitude  Longitude
# 0                                    Roselle Desserts  43.653447 -79.362017
# 1                                        Queen's Park  43.663946 -79.392180
# 2                                         UNIQLO ユニクロ  43.655910 -79.380641
# 3                               Gyu-Kaku Japanese BBQ  43.651422 -79.375047
# 4                                   Glen Manor Ravine  43.676821 -79.293942
# 5                                                LCBO  43.642944 -79.372440
# 6                                      Jimmy's Coffee  43.658421 -79.385613
# 7                                        Fiesta Farms  43.668471 -79.420485
# 8                              Nathan Phillips Square  43.652270 -79.383516
# 9                                The Greater Good Bar  43.669409 -79.439267
# 10                                       Harbourfront  43.639526 -79.380688
# ...

# %% [markdown]
# Displaying map of resturants

# %%
map_ = folium.Map(location=[43.653447, -79.362017], zoom_start=11)
for lat, lng, label in zip(Restu['Latitude'], Restu['Longitude'], Restu['Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_)  
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from sklearn.cluster import KMeans

# %%
labels=['Latitude','Longitude']

scaled=StandardScaler().fit_transform(Restu[labels])

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(scaled)

# %%
Restu['Labels']=kmeans.labels_
import matplotlib.cm as cm
import matplotlib.colors as colors
kclusters=6
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
map_ = folium.Map(location=[43.653447, -79.362017], zoom_start=11)

# %%
map_1 = folium.Map(location=[43.653447, -79.362017], zoom_start=11)
for lat, lon, poi, cluster in zip(Restu['Latitude'], Restu['Longitude'], Restu['Name'],Restu['Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_1)
map_1
